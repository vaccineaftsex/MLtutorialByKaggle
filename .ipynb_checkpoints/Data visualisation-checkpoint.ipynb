# %% [markdown]
# # Setup

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fifa_filepath = "../input/fifa.csv"
fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)# use the col 'date' as index to label the rows, and recognise it as date

# %% [markdown]
# # Trend
# ## Line chart

# %%
plt.figure(figsize = (16,6))  # width * height
plt.title("fifa data")
sns.lineplot(data = fifa_data)

plt.xlabel("Date")

# %% [markdown]
# * Plot a subset

# %%
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

# %% [markdown]
# # Relationship
# ## Bar charts

# %%
sns.barplot(x=flight_data.index, y=flight_data['NK'])

# %% [markdown]
# ## Heatmaps

# %%
sns.heatmap(data=flight_data, annot=True)  # "annot" ensures that the values for each cell appear on the chart

# %% [markdown]
# ## Scatter plot

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])  # colour-coded

# %% [markdown]
# * Regression line

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])  # add a regression line
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)  #draw two regression lines for colour-coded data

# %% [markdown]
# * catagorical scatter plot
#     * ![5.png](attachment:5.png)

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])

# %% [markdown]
# # Distributions
# ## Histograms

# %%
sns.distplot(a=iris_data['Petal Length (cm)'], kde=False)

# %% [markdown]
# ## Histograms for binary classification analysis

# %%
g = sns.FacetGrid(train, col = "Survived")  # survived = 0; survived = 1
g.map(plt.hist, 'Age', bins = 20)

# %% [markdown]
# ## kernel density estimate (KDE) plot

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)

# %% [markdown]
# * 2D KDE plot
#     * ![6.png](attachment:6.png)

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde")

# %% [markdown]
# ## Cross set plotting

# %%
sns.distplot(a=iris_set_data['Petal Length (cm)'], label="Iris-setosa", kde=False)
sns.distplot(a=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", kde=False)
sns.distplot(a=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", kde=False)

plt.title("Histogram of Petal Lengths, by Species")
plt.legend()

# %% [markdown]
# # Change Styles
# * Theme:  (1)"darkgrid", (2)"whitegrid", (3)"dark", (4)"white", and (5)"ticks"

# %%
sns.set_style("dark")

# %% [markdown]
# * Size

# %%
plt.figure(figsize=(12,6))
